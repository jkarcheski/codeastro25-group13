# %%
from package_skeleton import astro_ob, AGN 
import interactive_plot as ip

# %%
astroob_inst = astro_ob("AGN") #instance of astronomical object, its an AGN!
output = astroob_inst.get_spectra(2)
instance_list = []
for entry in output:
  instance = AGN("AGN",entry)
  instance_list.append(instance)

# %%
output
# Out:
# [{'spectrum': [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7b87f397dcf0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f397fc10>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f38102e0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f3810be0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f38122f0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f3813880>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f3848fd0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f384a6e0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f384bdf0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f3875540>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f3876c50>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f38a43a0>],
#   'plate': 266,
#   'mjd': 51602,
#   'fiberid': 103,
#   'objid': 1237648720679272605,
#   'ra': 146.741746268779,
#   'dec': -0.524666643412863,
#   'z': 0.1315158,
#   'class': 'GALAXY',
#   'subclass': 'AGN'},
#  {'spectrum': [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7b87f397f790>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f39c87f0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f38a7550>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f38a7ee0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f38d5ab0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f38d7640>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f3709210>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f370ada0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f3738970>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f373a500>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f37600d0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7b87f3761c60>],
#   'plate': 266,
#   'mjd': 51630,
#   'fiberid': 106,
#   'objid': 1237648720679272634,
#   'ra': 146.629629363229,
#   'dec': -0.465660529958573,
#   'z': 0.0893447,
#   'class': 'GALAXY',
#   'subclass': 'AGN'}]

# %%
ip.interactive_plots(instance_list, 'ra', 'dec')
